# %% [markdown]
# <a href="https://colab.research.google.com/github/SantiagoRios21/minitarea4/blob/master/minitarea4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #EI2001 : Ciencia de Datos en Astronomía
# **Profesores:** Pía Cortés, Daniela Barrientos, Matías Mattamala, Matías Suazo
#
# ##Minitarea 4: Análisis de Cubo de datos extragaláctico y querys.
#
# ###Objetivos:
# 1. Utilizar el paquete **astropy** para trabajar con unidades de medidas, coordenadas y fits.
# 2. Utilizar datos del google drive personal de cada uno.
# 3. Lectura de archivos *fits* en objetos extragalácticos en forma de cubo de datos.
# 4. Utilizar el paquete **astroquery** para hacer query de objetos del SDSS.

# %% [markdown]
# ###Instrucciones:
#
# 1. Lean cuidadosamente todo lo que viene ahora
# 2. Para hacer esta tarea deben que hacer un **fork** del repositorio en sus cuentas de GitHub.
# 3. Abrir [Google Colab](https://colab.research.google.com/) y seleccionar "abrir un archivo desde GitHub". Deben seleccionar su cuenta Github y escoger el repositorio que corresponde al fork que hicieron.
# 4. Si todo sale bien, debería abrirse una copia de este notebook en su cuenta de Google Colab.
# 5. Se adjuntan 6 mini actividades a completar. **TODAS** son necesarias y deben completar lo que se va pidiendo.
# 6. Cada vez que completen un ítem, deben guardar un avance en su fork de GitHub, de modo de **respaldar cada avance significativo**. Usen comentarios coherentes con cada respaldo "Sección 1 completa", "Tarea terminada", no solamente el que pone por defecto.

# %% [markdown]
# #1. FITS en Google Drive.
#
# En el siguiente enlace [(link)](https://docs.google.com/spreadsheets/d/1lT4h9Evwm6i2SBeuCK5dESTm8FijVZX7r6ixq-dt3ZM/edit#gid=0) se encuentra un excel con 30 galaxias observadas con CALIFA usando la técnica de Integral Field Spectroscopy (IFS). Debe escoger una galaxia que se encuentre disponible anotando su nombre en la casilla correspondiente a la galaxia que desee escoger (**No puede elegir una ya escojida por alguien más**). A cada galaxia le corresponde un link con el cual se pueden descargar los datos obtenidos por CALIFA para dicha galaxia en un cubo de datos **fits.gz**.
#
# Descargue el archivo correspondiente y súbalo a la cuenta de Google Drive vinculada con la cuenta de Google que utiliza para trabajar con [Google Colab](https://colab.research.google.com/). Asegúrese que el archivo de descarga corresponde con la galaxia seleccionada, en caso contrario hágalo saber al equipo docente.
#
# Ahora importe los paquetes y funciones necesarias vistas en clases para poder montar su unidad de Google drive. Si lo hace correctamente debiese aparecer un mensaje. Verifique que se muestra al correr esas líneas de código.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
filename=('/content/gdrive/My Drive/Colab Notebooks/NGC0192.V500.rscube.fits.gz')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# # 2. Visualización de la Galaxia
#
# En esta parte debe hacer lectura del cubo de datos **fits.gz** que se encuentra guardado en su Google Drive. Importe todos los paquetes que sean necesarios, no olvide leer el header (Ya sea en su forma normal o en WCS) e imprímalo en pantalla.

# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.wcs import WCS
import pandas as pd
hdu_o=fits.open(filename)
header=hdu_o[0].header
wcs=WCS(header)
wcs
data=hdu_o[0].data
print(wcs)
print('\nHEADER:')
header
# Out:
# WCS Keywords
#
# Number of WCS axes: 3
# CTYPE : 'RA---TAN'  'DEC--TAN'  'WAVELENGTH'
# CRVAL : 9.805681003291873  0.8640188099176296  3749.0
# CRPIX : 38.0  33.0  1.0
# CD1_1 CD1_2 CD1_3  : -0.00027777777777777  0.0  0.0
# CD2_1 CD2_2 CD2_3  : 0.0  0.000277777777777777  0.0
# CD3_1 CD3_2 CD3_3  : 0.0  0.0  2.0
# NAXIS : 77  72  1877
#
# HEADER:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                  -32 / number of bits per data pixel
# NAXIS   =                    3 / number of data axes
# NAXIS1  =                   77 / length of data axis 1
# NAXIS2  =                   72 / length of data axis 2
# NAXIS3  =                 1877
# EXTEND  =                    T / FITS dataset may contain extensions
# HIERARCH V500 PPAK P1 LONGSTRN = 'OGIP 1.0' / The HEASARC Long String Convention
# HIERARCH V500 PPAK P1 PVERSION = '1.0     ' / PMAS fitsheader version
# HIERARCH V500 PPAK P1 FILENAME = 'run226_00108a.fits' / original filename
# HIERARCH V500 PPAK P1 DATE = '2012-09-14T01:40:09' / file creation
# HIERARCH V500 PPAK P1 OBSERVER = 'Guijarro -- Sanchez'
# HIERARCH V500 PPAK P1 OBJECT = 'obj_7_p1_NGC 0192'
# HIERARCH V500 PPAK P1 CCD_TYPE = 'CCD231  '
# HIERARCH V500 PPAK P1 NAMPS = 4 / Number of Amplifiers
# HIERARCH V500 PPAK P1 NCCDS = 1 / Number of CCDs
# HIERARCH V500 PPAK P1 CAMPOS = -920.0 / camera position
# HIERARCH V500 PPAK P1 COLPOS = -15.0 / collimator position
# HIERARCH V500 PPAK P1 GROTPOS = 143.8 / grating position
# HIERARCH V500 PPAK P1 DEWAR = -117.333 / dewar temperature
# HIERARCH V500 PPAK P1 CALPOS = 120.0 / CAL actual position
# HIERARCH V500 PPAK P1 AGPOS = 4.8457E-05 / AG actual position
# HIERARCH V500 PPAK P1 FOCOLPOS = -8.2479900000000E-06 / FOCOL actual enc. positi
# HIERARCH V500 PPAK P1 FOFEPOS = 0.0 / FO Filter actual enc. position
# HIERARCH V500 PPAK P1 FOZPOS = 9.88372E-05 / FOZ stage actual enc. position
# HIERARCH V500 PPAK P1 FOCOLSL = 'none    ' / FO Collimator selection
# HIERARCH V500 PPAK P1 FOFESL = 'none    ' / FO Filter selection
# HIERARCH V500 PPAK P1 FIRST_AG = 1294 / A&G frame at begin of SPEC exposure
# HIERARCH V500 PPAK P1 DATE-OBS = '2012-09-14T01:40:09' / file creation
# HIERARCH V500 PPAK P1 POSTN-RA = 2404.9 / tel. position Right Ascension
# HIERARCH V500 PPAK P1 RA = 10.020416 / 00:40:04.9 RA [deg]
# HIERARCH V500 PPAK P1 POSTN-DE = 3679.75 / tel. position Declination
# HIERARCH V500 PPAK P1 DEC = 1.02215 / +01:01:19.8 DEC [deg]
# HIERARCH V500 PPAK P1 POSTN-HA = 1418.07 / tel. position Hour Angle
# HIERARCH V500 PPAK P1 HA = 5.908611 / 00:23:38.1 HA [deg]
# HIERARCH V500 PPAK P1 UNI-TIME = 6008.58 / Universal Time
# HIERARCH V500 PPAK P1 UTC = 6008.583011 / 01:40:08.6 U.T. at start [sec]
# HIERARCH V500 PPAK P1 UT_START = 6008.583011 / 01:40:08.6 U.T. at start [sec]
# HIERARCH V500 PPAK P1 SID-TIME = 3823.11 / Sidereal Time [sec]
# HIERARCH V500 PPAK P1 LST = 3823.113279 / 01:03:43.1 sid. time [sec]
# HIERARCH V500 PPAK P1 AIRMASS = 1.2454 / airmass
# HIERARCH V500 PPAK P1 JUL-DATE = 2456184.5703 / julian date
# HIERARCH V500 PPAK P1 MJD-OBS = 56184.07027331 / modified jul. date
# HIERARCH V500 PPAK P1 CAHA TEL GEOELEV = 2168 / elev. above sea
# HIERARCH V500 PPAK P1 CAHA TEL GEOLAT = 37.2236 / geographic lat.
# HIERARCH V500 PPAK P1 CAHA TEL GEOLON = -2.5463 / geographic long.
# HIERARCH V500 PPAK P1 CAHA TEL DOME.AZ = 11.6 / dome azimut [degr]
# HIERARCH V500 PPAK P1 CAHA TEL DOME.EL_LOW_E = 42.0 / dome door low lim.
# HIERARCH V500 PPAK P1 CAHA TEL DOME EL_UPP_E = 62.0 / dome door upper lim.
# HIERARCH V500 PPAK P1 CAHA TEL FOCU ID = 'CASS    ' / ID of used focus
# HIERARCH V500 PPAK P1 CAHA TEL MIRR S1 COLLAREA = 0.92 / eff. coll. area of S1 [
# HIERARCH V500 PPAK P1 CAHA TEL FOCU F_RATIO = 8.0 / f-ratio
# HIERARCH V500 PPAK P1 CAHA TEL FOCU LEN = 9.808 / focal length [m]
# HIERARCH V500 PPAK P1 CAHA TEL FOCU SCALE = 0.0478 / focus scale mm/arcsec
# HIERARCH V500 PPAK P1 CAHA TEL FOCU VALUE = 31.041 / focus rel. setting
# HIERARCH V500 PPAK P1 CAHA TEL POS SET RA = 274950.0 / 05:05:30.0 RA preset [sec
# HIERARCH V500 PPAK P1 CAHA TEL POS SET DEC = 52.831667 / +52:49:54.0 DEC preset
# HIERARCH V500 PPAK P1 CAHA TEL POS SET EQUINOX = 2000.0 / eq preset
# HIERARCH V500 PPAK P1 CAHA TEL POS AZ_START = 9.94 / telescope azimuth at start
# HIERARCH V500 PPAK P1 CAHA TEL POS EL_START = 53.39 / telescope elevation at sta
# HIERARCH V500 PPAK P1 CAHA TEL POS HA_START = 5.908611 / 00:23:38.1 HA [deg]
# HIERARCH V500 PPAK P1 CAHA GEN AMBI WIND SPEED = 4.4 / wind-speed[m/s]
# HIERARCH V500 PPAK P1 CAHA GEN AMBI WIND DIR = 2 / wind dir[deg.]
# HIERARCH V500 PPAK P1 CAHA GEN AMBI RHUM = 58 / relative humidity[%]
# HIERARCH V500 PPAK P1 CAHA GEN AMBI PRES = 776.4 / air pressure
# HIERARCH V500 PPAK P1 CAHA GEN AMBI TEMP = 8.800000000000001 / air-temperature[C
# HIERARCH V500 PPAK P1 CAHA ADA POSANG = 89.98 / position angle of adapter
# HIERARCH V500 PPAK P1 XBIN = 2 / x binning
# HIERARCH V500 PPAK P1 YBIN = 2 / y binning
# HIERARCH V500 PPAK P1 ACEGAIN = 5 / ace gain
# HIERARCH V500 PPAK P1 CDSTIME = 1 / ace cds time
# HIERARCH V500 PPAK P1 EXPTIME = 900 / exposure time [s]
# HIERARCH V500 PPAK P1 EXPTIMEM = 0 / exposure time [ms]
# HIERARCH V500 PPAK P1 EXPTYPE = 1 / exposure type 0
# HIERARCH V500 PPAK P1 LMPSH_1 = 0 / shutter lamp 1 (Hal)
# HIERARCH V500 PPAK P1 LMPSH_2 = 0 / shutter lamp 2 (Ne)
# HIERARCH V500 PPAK P1 LMPSH_3 = 0 / shutter lamp 3 (Ne
# HIERARCH V500 PPAK P1 LMPSH_4 = 0 / shutter lamp 4 (Hg)
# HIERARCH V500 PPAK P1 LMPSH_5 = 0 / shutter lamp 5 (Hg)
# HIERARCH V500 PPAK P1 LMPSH_6 = 0 / shutter lamp 6 (ThAr)
# HIERARCH V500 PPAK P1 PPAK_SH3 = 0 / PPAK CALUNIT Shutter
# HIERARCH V500 PPAK P1 LMPOW_1 = 0 / power lamp 1 (Hal)
# HIERARCH V500 PPAK P1 LMPOW_23 = 0 / power lamp 2+3 (Ne)
# HIERARCH V500 PPAK P1 LMPOW_45 = 0 / power lamp 4+5 (Hg)
# HIERARCH V500 PPAK P1 LMPOW_6 = 0 / power lamp 6 (ThAr)
# HIERARCH V500 PPAK P1 POLUNIT = 0 / polarimetric mode 1
# HIERARCH V500 PPAK P1 POLANGL1 = 0.0 / polarimeter angle 1
# HIERARCH V500 PPAK P1 POLANGL2 = 22.5 / polarimeter angle 2
# HIERARCH V500 PPAK P1 GRAT_ID = 9 / grating id
# HIERARCH V500 PPAK P1 NFIBERS = 382 / number of fibers
# HIERARCH V500 PPAK P1 IFU_TYPE = 'PPAK_GenI.1_DIFU_331_36_15' / type of int. fie
# HIERARCH V500 PPAK P1 IFU_CONF = 'PPAK_GenI.1_DIFU_331_36_15.ifu' / configuratio
# HIERARCH V500 PPAK P1 PPAK_FIL = 'none    ' / PPAK IFU FORED Filter
# HIERARCH V500 PPAK P1 PPAK_CUF = 'none    ' / PPAK Calibration Unit Filter
# HIERARCH V500 PPAK P1 PPAK_SHO = 0.0 / PPAK Calibration Shutter open time
# HIERARCH V500 PPAK P1 LAST_AG = 1346 / A&G frame at end of SPEC exposure
# HIERARCH V500 PPAK P1 WARNING = 'Warning ' / RON & GAIN are measured unbinned!
# HIERARCH V500 PPAK P1 CAHA TEL POS AZ_END = 16.11 / telescope azimuth at end [de
# HIERARCH V500 PPAK P1 CAHA TEL POS EL_END = 52.72 / telescope elevation at end [
# HIERARCH V500 PPAK P1 CAHA TEL POS HA_END = 9.676389 / 00:38:42.3 HA [deg] at en
# HIERARCH V500 PPAK P1 UT_END = 6910.383011 / 01:55:10.4 U.T. [sec]
# HIERARCH V500 PPAK P1 EXPOSURE_TIME = 900.0 / s exposure time
# HIERARCH V500 PPAK P1 IMAGETYP = 'real    ' / bias,real,dark,test,ramp,bsw
# HIERARCH V500 PPAK P1 DETSIZE = '[1:4096,1:4112]' / physical detector size
# HIERARCH V500 PPAK P1 PRESCAN = '[50,0]  ' / additional real existent prescan pi
# HIERARCH V500 PPAK P1 CCDSEC = '[1:1055,1:1035]' / image location of amplifier
# HIERARCH V500 PPAK P1 AMP1 GAIN = 1.293 / Gain value of CCD amplifier 1
# HIERARCH V500 PPAK P1 AMP2 GAIN = 1.148 / Gain value of CCD amplifier 2
# HIERARCH V500 PPAK P1 AMP3 GAIN = 1.286 / Gain value of CCD amplifier 3
# HIERARCH V500 PPAK P1 AMP4 GAIN = 1.25 / Gain value of CCD amplifier 4
# HIERARCH V500 PPAK P1 AMP1 RDNOISE = 2.877 / Read-out noise of CCD amplifier 1
# HIERARCH V500 PPAK P1 AMP2 RDNOISE = 2.73 / Read-out noise of CCD amplifier 2
# HIERARCH V500 PPAK P1 AMP3 RDNOISE = 2.855 / Read-out noise of CCD amplifier 3
# HIERARCH V500 PPAK P1 AMP4 RDNOISE = 2.57 / Read-out noise of CCD amplifier 4
# HIERARCH V500 PPAK P1 AMP1 OVERSCAN = 362.0 / Overscan median (bias) of CCD ampl
# HIERARCH V500 PPAK P1 AMP2 OVERSCAN = 504.0 / Overscan median (bias) of CCD ampl
# HIERARCH V500 PPAK P1 AMP3 OVERSCAN = 549.0 / Overscan median (bias) of CCD ampl
# HIERARCH V500 PPAK P1 AMP4 OVERSCAN = 563.0 / Overscan median (bias) of CCD ampl
# HIERARCH V500 PPAK P1 HVCOR = 9.050000000000001 / Heliocentric vel correction [k
# HIERARCH V500 PPAK P1 EXT_V = 0.13 / V-band atmospheric extinction
# HIERARCH V500 PPAK P1 EXT_V_SD = 0.008999999999999999 / std of V-band atmospheri
# HIERARCH V500 PPAK P1 PIPE FLEX YOFF = -0.0395 / flexure offset in y-direction
# HIERARCH V500 PPAK P1 PIPE FLEX YRMS = '0.0492  ' / flexure rms in y-direction
# DISPAXIS=                    3
# HIERARCH V500 PPAK P1 PIPE CDISP FWHM MIN = 2.130614757537842
# HIERARCH V500 PPAK P1 PIPE CDISP FWHM MAX = 3.123688697814941
# HIERARCH V500 PPAK P1 PIPE CDISP FWHM AVG = 2.38174297114484
# HIERARCH V500 PPAK P1 PIPE CDISP FWHM MED = 2.324381113052368
# HIERARCH V500 PPAK P1 PIPE CDISP FWHM SIG = 0.1791453049901121
# HIERARCH V500 PPAK P1 PIPE DISP RMS MEDIAN = '0.0500  ' / Median RMS of disp sol
# HIERARCH V500 PPAK P1 PIPE DISP RMS MIN = '0.0241  ' / Min RMS of disp sol
# HIERARCH V500 PPAK P1 PIPE DISP RMS MAX = '0.2389  ' / Max RMS of disp sol
# HIERARCH V500 PPAK P1 PIPE FLEX XOFF = 0.0683 / flexure offset in x-direction
# HIERARCH V500 PPAK P1 PIPE FLEX XRMS = 0.1562 / flexure rms in x-direction
# HIERARCH V500 PPAK P1 PIPE SPEC RES = 6.0 / FWHM in A of spectral resolution
# CRVAL1  =    9.805681003291873 / RA at CRPIX1 in deg
# CDELT1  =                  1.0
# CRPIX1  =                   38 / Ref pixel for WCS
# HIERARCH V500 PPAK P1 PIPE NSKY FIB = 30 / Number of averaged sky fibers
# HIERARCH V500 PPAK P1 PIPE SKY MEAN = 20.92 / Mean sky brightness of sky fibers
# HIERARCH V500 PPAK P1 PIPE SKY MIN = 20.86 / Minium sky brightness of sky fibers
# HIERARCH V500 PPAK P1 PIPE SKY MAX = 20.95 / Maximum sky brightness of sky fiber
# HIERARCH V500 PPAK P1 PIPE SKY RMS = 0.02 / RMS sky brightness of sky fibers
# HIERARCH V500 PPAK P1 PIPE CONT = 'run226_00106.fits' / Name of the continuum fr
# HIERARCH V500 PPAK P1 PIPE CONT MST = 0 / master TRACE used
# HIERARCH V500 PPAK P1 PIPE ARC = 'run226_00107.fits' / Name of the arc frame
# HIERARCH V500 PPAK P1 PIPE ARC MST = 0 / master ARC lamp used
# HIERARCH V500 PPAK P1 PIPE WOFFSET = 0.007 / wavelength offset of OI 5777 sky li
# HIERARCH V500 PPAK P1 PIPE WRMS = 0.048 / offset RMS of OI 5777 sky line
# HIERARCH V500 PIPE P1 APER FLUX = 16.521 / V_Johnson band flux (30.0arcsec diame
# HIERARCH V500 PIPE P1 APER ERR = 0.07000000000000001 / V_Johnson band error (30.
# HIERARCH V500 PIPE P1 RELFLUX START = 4500.0 / Start wave for poly fit
# HIERARCH V500 PIPE P1 RELFLUX END = 7000.0 / End wave for poly fit
# HIERARCH V500 PIPE P1 RELFLUX POLY0 = '9.906E-01' / Polynomial coefficient
# HIERARCH V500 PIPE P1 RELFLUX POLY1 = '5.106E-06' / Polynomial coefficient
# HIERARCH V500 PIPE P1 PIPE REGISTER = 1 / Possibilty of registering for this poi
# HIERARCH V500 PIPE P1 PIPE OFFX = 0.75 / IFU RA offset from ref coordinate
# HIERARCH V500 PIPE P1 PIPE OFFY = -4.75 / IFU DEC offset from ref coordinate
# HIERARCH V500 PIPE P1 PIPE CHISQ = 0.71 / CHISQ of image matching
# HIERARCH V500 PIPE P1 PIPE VALIDFIB = 320 / Valid fibers for image matching
# HIERARCH V500 PIPE P1 PIPE PHOTSCL = 0.931 / photometric scale factor
# HIERARCH V500 PPAK P2 LONGSTRN = 'OGIP 1.0' / The HEASARC Long String Convention
# HIERARCH V500 PPAK P2 PVERSION = '1.0     ' / PMAS fitsheader version
# HIERARCH V500 PPAK P2 FILENAME = 'run226_00109a.fits' / original filename
# HIERARCH V500 PPAK P2 DATE = '2012-09-14T01:56:25' / file creation
# HIERARCH V500 PPAK P2 OBSERVER = 'Guijarro -- Sanchez'
# HIERARCH V500 PPAK P2 OBJECT = 'obj_7_p2_NGC 0192'
# HIERARCH V500 PPAK P2 CCD_TYPE = 'CCD231  '
# HIERARCH V500 PPAK P2 NAMPS = 4 / Number of Amplifiers
# HIERARCH V500 PPAK P2 NCCDS = 1 / Number of CCDs
# HIERARCH V500 PPAK P2 CAMPOS = -920.0 / camera position
# HIERARCH V500 PPAK P2 COLPOS = -16.0 / collimator position
# HIERARCH V500 PPAK P2 GROTPOS = 143.8 / grating position
# HIERARCH V500 PPAK P2 DEWAR = -117.072 / dewar temperature
# HIERARCH V500 PPAK P2 CALPOS = 120.0 / CAL actual position
# HIERARCH V500 PPAK P2 AGPOS = 4.8457E-05 / AG actual position
# HIERARCH V500 PPAK P2 FOCOLPOS = -8.2479900000000E-06 / FOCOL actual enc. positi
# HIERARCH V500 PPAK P2 FOFEPOS = 0.0 / FO Filter actual enc. position
# HIERARCH V500 PPAK P2 FOZPOS = 9.88372E-05 / FOZ stage actual enc. position
# HIERARCH V500 PPAK P2 FOCOLSL = 'none    ' / FO Collimator selection
# HIERARCH V500 PPAK P2 FOFESL = 'none    ' / FO Filter selection
# HIERARCH V500 PPAK P2 FIRST_AG = 1349 / A&G frame at begin of SPEC exposure
# HIERARCH V500 PPAK P2 DATE-OBS = '2012-09-14T01:56:25' / file creation
# HIERARCH V500 PPAK P2 POSTN-RA = 2404.5 / tel. position Right Ascension
# HIERARCH V500 PPAK P2 RA = 10.018763 / 00:40:04.5 RA [deg]
# HIERARCH V500 PPAK P2 POSTN-DE = 3676.59 / tel. position Declination
# HIERARCH V500 PPAK P2 DEC = 1.02128 / +01:01:16.6 DEC [deg]
# HIERARCH V500 PPAK P2 POSTN-HA = 2397.93 / tel. position Hour Angle
# HIERARCH V500 PPAK P2 HA = 9.991389 / 00:39:57.9 HA [deg]
# HIERARCH V500 PPAK P2 UNI-TIME = 6985.43 / Universal Time
# HIERARCH V500 PPAK P2 UTC = 6985.433011 / 01:56:25.4 U.T. at start [sec]
# HIERARCH V500 PPAK P2 UT_START = 6985.433011 / 01:56:25.4 U.T. at start [sec]
# HIERARCH V500 PPAK P2 SID-TIME = 4802.64 / Sidereal Time [sec]
# HIERARCH V500 PPAK P2 LST = 4802.637805 / 01:20:02.6 sid. time [sec]
# HIERARCH V500 PPAK P2 AIRMASS = 1.25764 / airmass
# HIERARCH V500 PPAK P2 JUL-DATE = 2456184.5816 / julian date
# HIERARCH V500 PPAK P2 MJD-OBS = 56184.08158165 / modified jul. date
# HIERARCH V500 PPAK P2 CAHA TEL GEOELEV = 2168 / elev. above sea
# HIERARCH V500 PPAK P2 CAHA TEL GEOLAT = 37.2236 / geographic lat.
# HIERARCH V500 PPAK P2 CAHA TEL GEOLON = -2.5463 / geographic long.
# HIERARCH V500 PPAK P2 CAHA TEL DOME.AZ = 11.6 / dome azimut [degr]
# HIERARCH V500 PPAK P2 CAHA TEL DOME.EL_LOW_E = 42.0 / dome door low lim.
# HIERARCH V500 PPAK P2 CAHA TEL DOME EL_UPP_E = 62.0 / dome door upper lim.
# HIERARCH V500 PPAK P2 CAHA TEL FOCU ID = 'CASS    ' / ID of used focus
# HIERARCH V500 PPAK P2 CAHA TEL MIRR S1 COLLAREA = 0.92 / eff. coll. area of S1 [
# HIERARCH V500 PPAK P2 CAHA TEL FOCU F_RATIO = 8.0 / f-ratio
# HIERARCH V500 PPAK P2 CAHA TEL FOCU LEN = 9.808 / focal length [m]
# HIERARCH V500 PPAK P2 CAHA TEL FOCU SCALE = 0.0478 / focus scale mm/arcsec
# HIERARCH V500 PPAK P2 CAHA TEL FOCU VALUE = 31.041 / focus rel. setting
# HIERARCH V500 PPAK P2 CAHA TEL POS SET RA = 274950.0 / 05:05:30.0 RA preset [sec
# HIERARCH V500 PPAK P2 CAHA TEL POS SET DEC = 52.831667 / +52:49:54.0 DEC preset
# HIERARCH V500 PPAK P2 CAHA TEL POS SET EQUINOX = 2000.0 / eq preset
# HIERARCH V500 PPAK P2 CAHA TEL POS AZ_START = 16.61 / telescope azimuth at start
# HIERARCH V500 PPAK P2 CAHA TEL POS EL_START = 52.64 / telescope elevation at sta
# HIERARCH V500 PPAK P2 CAHA TEL POS HA_START = 9.991389 / 00:39:57.9 HA [deg]
# HIERARCH V500 PPAK P2 CAHA GEN AMBI WIND SPEED = 2.6 / wind-speed[m/s]
# HIERARCH V500 PPAK P2 CAHA GEN AMBI WIND DIR = 6 / wind dir[deg.]
# HIERARCH V500 PPAK P2 CAHA GEN AMBI RHUM = 60 / relative humidity[%]
# HIERARCH V500 PPAK P2 CAHA GEN AMBI PRES = 776.4 / air pressure
# HIERARCH V500 PPAK P2 CAHA GEN AMBI TEMP = 8.6 / air-temperature[Celsius]
# HIERARCH V500 PPAK P2 CAHA ADA POSANG = 89.98 / position angle of adapter
# HIERARCH V500 PPAK P2 XBIN = 2 / x binning
# HIERARCH V500 PPAK P2 YBIN = 2 / y binning
# HIERARCH V500 PPAK P2 ACEGAIN = 5 / ace gain
# HIERARCH V500 PPAK P2 CDSTIME = 1 / ace cds time
# HIERARCH V500 PPAK P2 EXPTIME = 900 / exposure time [s]
# HIERARCH V500 PPAK P2 EXPTIMEM = 0 / exposure time [ms]
# HIERARCH V500 PPAK P2 EXPTYPE = 1 / exposure type 0
# HIERARCH V500 PPAK P2 LMPSH_1 = 0 / shutter lamp 1 (Hal)
# HIERARCH V500 PPAK P2 LMPSH_2 = 0 / shutter lamp 2 (Ne)
# HIERARCH V500 PPAK P2 LMPSH_3 = 0 / shutter lamp 3 (Ne
# HIERARCH V500 PPAK P2 LMPSH_4 = 0 / shutter lamp 4 (Hg)
# HIERARCH V500 PPAK P2 LMPSH_5 = 0 / shutter lamp 5 (Hg)
# HIERARCH V500 PPAK P2 LMPSH_6 = 0 / shutter lamp 6 (ThAr)
# HIERARCH V500 PPAK P2 PPAK_SH3 = 0 / PPAK CALUNIT Shutter
# HIERARCH V500 PPAK P2 LMPOW_1 = 0 / power lamp 1 (Hal)
# HIERARCH V500 PPAK P2 LMPOW_23 = 0 / power lamp 2+3 (Ne)
# HIERARCH V500 PPAK P2 LMPOW_45 = 0 / power lamp 4+5 (Hg)
# HIERARCH V500 PPAK P2 LMPOW_6 = 0 / power lamp 6 (ThAr)
# HIERARCH V500 PPAK P2 POLUNIT = 0 / polarimetric mode 1
# HIERARCH V500 PPAK P2 POLANGL1 = 0.0 / polarimeter angle 1
# HIERARCH V500 PPAK P2 POLANGL2 = 22.5 / polarimeter angle 2
# HIERARCH V500 PPAK P2 GRAT_ID = 9 / grating id
# HIERARCH V500 PPAK P2 NFIBERS = 382 / number of fibers
# HIERARCH V500 PPAK P2 IFU_TYPE = 'PPAK_GenI.1_DIFU_331_36_15' / type of int. fie
# HIERARCH V500 PPAK P2 IFU_CONF = 'PPAK_GenI.1_DIFU_331_36_15.ifu' / configuratio
# HIERARCH V500 PPAK P2 PPAK_FIL = 'none    ' / PPAK IFU FORED Filter
# HIERARCH V500 PPAK P2 PPAK_CUF = 'none    ' / PPAK Calibration Unit Filter
# HIERARCH V500 PPAK P2 PPAK_SHO = 0.0 / PPAK Calibration Shutter open time
# HIERARCH V500 PPAK P2 LAST_AG = 1400 / A&G frame at end of SPEC exposure
# HIERARCH V500 PPAK P2 WARNING = 'Warning ' / RON & GAIN are measured unbinned!
# HIERARCH V500 PPAK P2 CAHA TEL POS AZ_END = 22.53 / telescope azimuth at end [de
# HIERARCH V500 PPAK P2 CAHA TEL POS EL_END = 51.64 / telescope elevation at end [
# HIERARCH V500 PPAK P2 CAHA TEL POS HA_END = 13.758889 / 00:55:02.1 HA [deg] at e
# HIERARCH V500 PPAK P2 UT_END = 7887.183011 / 02:11:27.2 U.T. [sec]
# HIERARCH V500 PPAK P2 EXPOSURE_TIME = 900.0 / s exposure time
# HIERARCH V500 PPAK P2 IMAGETYP = 'real    ' / bias,real,dark,test,ramp,bsw
# HIERARCH V500 PPAK P2 DETSIZE = '[1:4096,1:4112]' / physical detector size
# HIERARCH V500 PPAK P2 PRESCAN = '[50,0]  ' / additional real existent prescan pi
# HIERARCH V500 PPAK P2 CCDSEC = '[1:1055,1:1035]' / image location of amplifier
# HIERARCH V500 PPAK P2 AMP1 GAIN = 1.293 / Gain value of CCD amplifier 1
# HIERARCH V500 PPAK P2 AMP2 GAIN = 1.148 / Gain value of CCD amplifier 2
# HIERARCH V500 PPAK P2 AMP3 GAIN = 1.286 / Gain value of CCD amplifier 3
# HIERARCH V500 PPAK P2 AMP4 GAIN = 1.25 / Gain value of CCD amplifier 4
# HIERARCH V500 PPAK P2 AMP1 RDNOISE = 2.877 / Read-out noise of CCD amplifier 1
# HIERARCH V500 PPAK P2 AMP2 RDNOISE = 2.73 / Read-out noise of CCD amplifier 2
# HIERARCH V500 PPAK P2 AMP3 RDNOISE = 2.855 / Read-out noise of CCD amplifier 3
# HIERARCH V500 PPAK P2 AMP4 RDNOISE = 2.57 / Read-out noise of CCD amplifier 4
# HIERARCH V500 PPAK P2 AMP1 OVERSCAN = 362.0 / Overscan median (bias) of CCD ampl
# HIERARCH V500 PPAK P2 AMP2 OVERSCAN = 504.0 / Overscan median (bias) of CCD ampl
# HIERARCH V500 PPAK P2 AMP3 OVERSCAN = 549.0 / Overscan median (bias) of CCD ampl
# HIERARCH V500 PPAK P2 AMP4 OVERSCAN = 563.0 / Overscan median (bias) of CCD ampl
# HIERARCH V500 PPAK P2 HVCOR = 9.07 / Heliocentric vel correction [km/s]
# HIERARCH V500 PPAK P2 EXT_V = 0.132 / V-band atmospheric extinction
# HIERARCH V500 PPAK P2 EXT_V_SD = 0.008999999999999999 / std of V-band atmospheri
# HIERARCH V500 PPAK P2 PIPE FLEX YOFF = -0.0524 / flexure offset in y-direction
# HIERARCH V500 PPAK P2 PIPE FLEX YRMS = '0.0498  ' / flexure rms in y-direction
# HIERARCH V500 PPAK P2 PIPE CDISP FWHM MIN = 2.130614757537842
# HIERARCH V500 PPAK P2 PIPE CDISP FWHM MAX = 3.123688697814941
# HIERARCH V500 PPAK P2 PIPE CDISP FWHM AVG = 2.38174297114484
# HIERARCH V500 PPAK P2 PIPE CDISP FWHM MED = 2.324381113052368
# HIERARCH V500 PPAK P2 PIPE CDISP FWHM SIG = 0.1791453049901121
# HIERARCH V500 PPAK P2 PIPE DISP RMS MEDIAN = '0.0500  ' / Median RMS of disp sol
# HIERARCH V500 PPAK P2 PIPE DISP RMS MIN = '0.0241  ' / Min RMS of disp sol
# HIERARCH V500 PPAK P2 PIPE DISP RMS MAX = '0.2389  ' / Max RMS of disp sol
# HIERARCH V500 PPAK P2 PIPE FLEX XOFF = 0.0559 / flexure offset in x-direction
# HIERARCH V500 PPAK P2 PIPE FLEX XRMS = 0.1467 / flexure rms in x-direction
# HIERARCH V500 PPAK P2 PIPE SPEC RES = 6.0 / FWHM in A of spectral resolution
# HIERARCH V500 PPAK P2 PIPE NSKY FIB = 30 / Number of averaged sky fibers
# HIERARCH V500 PPAK P2 PIPE SKY MEAN = 20.89 / Mean sky brightness of sky fibers
# HIERARCH V500 PPAK P2 PIPE SKY MIN = 20.82 / Minium sky brightness of sky fibers
# HIERARCH V500 PPAK P2 PIPE SKY MAX = 20.92 / Maximum sky brightness of sky fiber
# HIERARCH V500 PPAK P2 PIPE SKY RMS = 0.02 / RMS sky brightness of sky fibers
# HIERARCH V500 PPAK P2 PIPE CONT = 'run226_00106.fits' / Name of the continuum fr
# HIERARCH V500 PPAK P2 PIPE CONT MST = 0 / master TRACE used
# HIERARCH V500 PPAK P2 PIPE ARC = 'run226_00107.fits' / Name of the arc frame
# HIERARCH V500 PPAK P2 PIPE ARC MST = 0 / master ARC lamp used
# HIERARCH V500 PPAK P2 PIPE WOFFSET = 0.007 / wavelength offset of OI 5777 sky li
# HIERARCH V500 PPAK P2 PIPE WRMS = 0.048 / offset RMS of OI 5777 sky line
# HIERARCH V500 PIPE P2 APER FLUX = 16.339 / V_Johnson band flux (30.0arcsec diame
# HIERARCH V500 PIPE P2 APER ERR = 0.07000000000000001 / V_Johnson band error (30.
# HIERARCH V500 PIPE P2 RELFLUX START = 4500.0 / Start wave for poly fit
# HIERARCH V500 PIPE P2 RELFLUX END = 7000.0 / End wave for poly fit
# HIERARCH V500 PIPE P2 RELFLUX POLY0 = '9.835E-01' / Polynomial coefficient
# HIERARCH V500 PIPE P2 RELFLUX POLY1 = '8.360E-06' / Polynomial coefficient
# HIERARCH V500 PIPE P2 PIPE REGISTER = 1 / Possibilty of registering for this poi
# HIERARCH V500 PIPE P2 PIPE OFFX = 1.0 / IFU RA offset from ref coordinate
# HIERARCH V500 PIPE P2 PIPE OFFY = -4.75 / IFU DEC offset from ref coordinate
# HIERARCH V500 PIPE P2 PIPE CHISQ = 0.76 / CHISQ of image matching
# HIERARCH V500 PIPE P2 PIPE VALIDFIB = 324 / Valid fibers for image matching
# HIERARCH V500 PIPE P2 PIPE PHOTSCL = 0.922 / photometric scale factor
# HIERARCH V500 PPAK P3 LONGSTRN = 'OGIP 1.0' / The HEASARC Long String Convention
# HIERARCH V500 PPAK P3 PVERSION = '1.0     ' / PMAS fitsheader version
# HIERARCH V500 PPAK P3 FILENAME = 'run226_00110a.fits' / original filename
# HIERARCH V500 PPAK P3 DATE = '2012-09-14T02:13:11' / file creation
# HIERARCH V500 PPAK P3 OBSERVER = 'Guijarro -- Sanchez'
# HIERARCH V500 PPAK P3 OBJECT = 'obj_7_p3_NGC 0192'
# HIERARCH V500 PPAK P3 CCD_TYPE = 'CCD231  '
# HIERARCH V500 PPAK P3 NAMPS = 4 / Number of Amplifiers
# HIERARCH V500 PPAK P3 NCCDS = 1 / Number of CCDs
# HIERARCH V500 PPAK P3 CAMPOS = -920.0 / camera position
# HIERARCH V500 PPAK P3 COLPOS = -18.0 / collimator position
# HIERARCH V500 PPAK P3 GROTPOS = 143.8 / grating position
# HIERARCH V500 PPAK P3 DEWAR = -117.072 / dewar temperature
# HIERARCH V500 PPAK P3 CALPOS = 120.0 / CAL actual position
# HIERARCH V500 PPAK P3 AGPOS = 4.8457E-05 / AG actual position
# HIERARCH V500 PPAK P3 FOCOLPOS = -8.2479900000000E-06 / FOCOL actual enc. positi
# HIERARCH V500 PPAK P3 FOFEPOS = 0.0 / FO Filter actual enc. position
# HIERARCH V500 PPAK P3 FOZPOS = 9.88372E-05 / FOZ stage actual enc. position
# HIERARCH V500 PPAK P3 FOCOLSL = 'none    ' / FO Collimator selection
# HIERARCH V500 PPAK P3 FOFESL = 'none    ' / FO Filter selection
# HIERARCH V500 PPAK P3 FIRST_AG = 1405 / A&G frame at begin of SPEC exposure
# HIERARCH V500 PPAK P3 DATE-OBS = '2012-09-14T02:13:11' / file creation
# HIERARCH V500 PPAK P3 POSTN-RA = 2404.51 / tel. position Right Ascension
# HIERARCH V500 PPAK P3 RA = 10.018773 / 00:40:04.5 RA [deg]
# HIERARCH V500 PPAK P3 POSTN-DE = 3688.82 / tel. position Declination
# HIERARCH V500 PPAK P3 DEC = 1.02467 / +01:01:28.8 DEC [deg]
# HIERARCH V500 PPAK P3 POSTN-HA = 3405.4 / tel. position Hour Angle
# HIERARCH V500 PPAK P3 HA = 14.189167 / 00:56:45.4 HA [deg]
# HIERARCH V500 PPAK P3 UNI-TIME = 7990.18 / Universal Time
# HIERARCH V500 PPAK P3 UTC = 7990.183011 / 02:13:10.2 U.T. at start [sec]
# HIERARCH V500 PPAK P3 UT_START = 7990.183011 / 02:13:10.2 U.T. at start [sec]
# HIERARCH V500 PPAK P3 SID-TIME = 5810.14 / Sidereal Time [sec]
# HIERARCH V500 PPAK P3 LST = 5810.13872 / 01:36:50.1 sid. time [sec]
# HIERARCH V500 PPAK P3 AIRMASS = 1.27715 / airmass
# HIERARCH V500 PPAK P3 JUL-DATE = 2456184.5932 / julian date
# HIERARCH V500 PPAK P3 MJD-OBS = 56184.09321298 / modified jul. date
# HIERARCH V500 PPAK P3 CAHA TEL GEOELEV = 2168 / elev. above sea
# HIERARCH V500 PPAK P3 CAHA TEL GEOLAT = 37.2236 / geographic lat.
# HIERARCH V500 PPAK P3 CAHA TEL GEOLON = -2.5463 / geographic long.
# HIERARCH V500 PPAK P3 CAHA TEL DOME.AZ = 21.5 / dome azimut [degr]
# HIERARCH V500 PPAK P3 CAHA TEL DOME.EL_LOW_E = 42.0 / dome door low lim.
# HIERARCH V500 PPAK P3 CAHA TEL DOME EL_UPP_E = 62.0 / dome door upper lim.
# HIERARCH V500 PPAK P3 CAHA TEL FOCU ID = 'CASS    ' / ID of used focus
# HIERARCH V500 PPAK P3 CAHA TEL MIRR S1 COLLAREA = 0.92 / eff. coll. area of S1 [
# HIERARCH V500 PPAK P3 CAHA TEL FOCU F_RATIO = 8.0 / f-ratio
# HIERARCH V500 PPAK P3 CAHA TEL FOCU LEN = 9.808 / focal length [m]
# HIERARCH V500 PPAK P3 CAHA TEL FOCU SCALE = 0.0478 / focus scale mm/arcsec
# HIERARCH V500 PPAK P3 CAHA TEL FOCU VALUE = 30.997 / focus rel. setting
# HIERARCH V500 PPAK P3 CAHA TEL POS SET RA = 274950.0 / 05:05:30.0 RA preset [sec
# HIERARCH V500 PPAK P3 CAHA TEL POS SET DEC = 52.831667 / +52:49:54.0 DEC preset
# HIERARCH V500 PPAK P3 CAHA TEL POS SET EQUINOX = 2000.0 / eq preset
# HIERARCH V500 PPAK P3 CAHA TEL POS AZ_START = 23.19 / telescope azimuth at start
# HIERARCH V500 PPAK P3 CAHA TEL POS EL_START = 51.51 / telescope elevation at sta
# HIERARCH V500 PPAK P3 CAHA TEL POS HA_START = 14.189167 / 00:56:45.4 HA [deg]
# HIERARCH V500 PPAK P3 CAHA GEN AMBI WIND SPEED = 2.1 / wind-speed[m/s]
# HIERARCH V500 PPAK P3 CAHA GEN AMBI WIND DIR = 359 / wind dir[deg.]
# HIERARCH V500 PPAK P3 CAHA GEN AMBI RHUM = 64 / relative humidity[%]
# HIERARCH V500 PPAK P3 CAHA GEN AMBI PRES = 776.4 / air pressure
# HIERARCH V500 PPAK P3 CAHA GEN AMBI TEMP = 8.4 / air-temperature[Celsius]
# HIERARCH V500 PPAK P3 CAHA ADA POSANG = 89.98 / position angle of adapter
# HIERARCH V500 PPAK P3 XBIN = 2 / x binning
# HIERARCH V500 PPAK P3 YBIN = 2 / y binning
# HIERARCH V500 PPAK P3 ACEGAIN = 5 / ace gain
# HIERARCH V500 PPAK P3 CDSTIME = 1 / ace cds time
# HIERARCH V500 PPAK P3 EXPTIME = 900 / exposure time [s]
# HIERARCH V500 PPAK P3 EXPTIMEM = 0 / exposure time [ms]
# HIERARCH V500 PPAK P3 EXPTYPE = 1 / exposure type 0
# HIERARCH V500 PPAK P3 LMPSH_1 = 0 / shutter lamp 1 (Hal)
# HIERARCH V500 PPAK P3 LMPSH_2 = 0 / shutter lamp 2 (Ne)
# HIERARCH V500 PPAK P3 LMPSH_3 = 0 / shutter lamp 3 (Ne
# HIERARCH V500 PPAK P3 LMPSH_4 = 0 / shutter lamp 4 (Hg)
# HIERARCH V500 PPAK P3 LMPSH_5 = 0 / shutter lamp 5 (Hg)
# HIERARCH V500 PPAK P3 LMPSH_6 = 0 / shutter lamp 6 (ThAr)
# HIERARCH V500 PPAK P3 PPAK_SH3 = 0 / PPAK CALUNIT Shutter
# HIERARCH V500 PPAK P3 LMPOW_1 = 0 / power lamp 1 (Hal)
# HIERARCH V500 PPAK P3 LMPOW_23 = 0 / power lamp 2+3 (Ne)
# HIERARCH V500 PPAK P3 LMPOW_45 = 0 / power lamp 4+5 (Hg)
# HIERARCH V500 PPAK P3 LMPOW_6 = 0 / power lamp 6 (ThAr)
# HIERARCH V500 PPAK P3 POLUNIT = 0 / polarimetric mode 1
# HIERARCH V500 PPAK P3 POLANGL1 = 0.0 / polarimeter angle 1
# HIERARCH V500 PPAK P3 POLANGL2 = 22.5 / polarimeter angle 2
# HIERARCH V500 PPAK P3 GRAT_ID = 9 / grating id
# HIERARCH V500 PPAK P3 NFIBERS = 382 / number of fibers
# HIERARCH V500 PPAK P3 IFU_TYPE = 'PPAK_GenI.1_DIFU_331_36_15' / type of int. fie
# HIERARCH V500 PPAK P3 IFU_CONF = 'PPAK_GenI.1_DIFU_331_36_15.ifu' / configuratio
# HIERARCH V500 PPAK P3 PPAK_FIL = 'none    ' / PPAK IFU FORED Filter
# HIERARCH V500 PPAK P3 PPAK_CUF = 'none    ' / PPAK Calibration Unit Filter
# HIERARCH V500 PPAK P3 PPAK_SHO = 0.0 / PPAK Calibration Shutter open time
# HIERARCH V500 PPAK P3 LAST_AG = 1454 / A&G frame at end of SPEC exposure
# HIERARCH V500 PPAK P3 WARNING = 'Warning ' / RON & GAIN are measured unbinned!
# HIERARCH V500 PPAK P3 CAHA TEL POS AZ_END = 28.78 / telescope azimuth at end [de
# HIERARCH V500 PPAK P3 CAHA TEL POS EL_END = 50.19 / telescope elevation at end [
# HIERARCH V500 PPAK P3 CAHA TEL POS HA_END = 17.957778 / 01:11:49.9 HA [deg] at e
# HIERARCH V500 PPAK P3 UT_END = 8892.083011000001 / 02:28:12.1 U.T. [sec]
# HIERARCH V500 PPAK P3 EXPOSURE_TIME = 900.0 / s exposure time
# HIERARCH V500 PPAK P3 IMAGETYP = 'real    ' / bias,real,dark,test,ramp,bsw
# HIERARCH V500 PPAK P3 DETSIZE = '[1:4096,1:4112]' / physical detector size
# HIERARCH V500 PPAK P3 PRESCAN = '[50,0]  ' / additional real existent prescan pi
# HIERARCH V500 PPAK P3 CCDSEC = '[1:1055,1:1035]' / image location of amplifier
# HIERARCH V500 PPAK P3 AMP1 GAIN = 1.293 / Gain value of CCD amplifier 1
# HIERARCH V500 PPAK P3 AMP2 GAIN = 1.148 / Gain value of CCD amplifier 2
# HIERARCH V500 PPAK P3 AMP3 GAIN = 1.286 / Gain value of CCD amplifier 3
# HIERARCH V500 PPAK P3 AMP4 GAIN = 1.25 / Gain value of CCD amplifier 4
# HIERARCH V500 PPAK P3 AMP1 RDNOISE = 2.877 / Read-out noise of CCD amplifier 1
# HIERARCH V500 PPAK P3 AMP2 RDNOISE = 2.73 / Read-out noise of CCD amplifier 2
# HIERARCH V500 PPAK P3 AMP3 RDNOISE = 2.855 / Read-out noise of CCD amplifier 3
# HIERARCH V500 PPAK P3 AMP4 RDNOISE = 2.57 / Read-out noise of CCD amplifier 4
# HIERARCH V500 PPAK P3 AMP1 OVERSCAN = 361.0 / Overscan median (bias) of CCD ampl
# HIERARCH V500 PPAK P3 AMP2 OVERSCAN = 503.0 / Overscan median (bias) of CCD ampl
# HIERARCH V500 PPAK P3 AMP3 OVERSCAN = 549.0 / Overscan median (bias) of CCD ampl
# HIERARCH V500 PPAK P3 AMP4 OVERSCAN = 563.0 / Overscan median (bias) of CCD ampl
# HIERARCH V500 PPAK P3 HVCOR = 9.09 / Heliocentric vel correction [km/s]
# HIERARCH V500 PPAK P3 EXT_V = 0.133 / V-band atmospheric extinction
# HIERARCH V500 PPAK P3 EXT_V_SD = 0.008 / std of V-band atmospheric extinction
# HIERARCH V500 PPAK P3 PIPE FLEX YOFF = -0.0431 / flexure offset in y-direction
# HIERARCH V500 PPAK P3 PIPE FLEX YRMS = '0.0501  ' / flexure rms in y-direction
# HIERARCH V500 PPAK P3 PIPE CDISP FWHM MIN = 2.130614757537842
# HIERARCH V500 PPAK P3 PIPE CDISP FWHM MAX = 3.123688697814941
# HIERARCH V500 PPAK P3 PIPE CDISP FWHM AVG = 2.38174297114484
# HIERARCH V500 PPAK P3 PIPE CDISP FWHM MED = 2.324381113052368
# HIERARCH V500 PPAK P3 PIPE CDISP FWHM SIG = 0.1791453049901121
# HIERARCH V500 PPAK P3 PIPE DISP RMS MEDIAN = '0.0500  ' / Median RMS of disp sol
# HIERARCH V500 PPAK P3 PIPE DISP RMS MIN = '0.0241  ' / Min RMS of disp sol
# HIERARCH V500 PPAK P3 PIPE DISP RMS MAX = '0.2389  ' / Max RMS of disp sol
# HIERARCH V500 PPAK P3 PIPE FLEX XOFF = 0.1835 / flexure offset in x-direction
# HIERARCH V500 PPAK P3 PIPE FLEX XRMS = 0.1434 / flexure rms in x-direction
# HIERARCH V500 PPAK P3 PIPE SPEC RES = 6.0 / FWHM in A of spectral resolution
# HIERARCH V500 PPAK P3 PIPE NSKY FIB = 30 / Number of averaged sky fibers
# HIERARCH V500 PPAK P3 PIPE SKY MEAN = 20.89 / Mean sky brightness of sky fibers
# HIERARCH V500 PPAK P3 PIPE SKY MIN = 20.83 / Minium sky brightness of sky fibers
# HIERARCH V500 PPAK P3 PIPE SKY MAX = 20.92 / Maximum sky brightness of sky fiber
# HIERARCH V500 PPAK P3 PIPE SKY RMS = 0.02 / RMS sky brightness of sky fibers
# HIERARCH V500 PPAK P3 PIPE CONT = 'run226_00106.fits' / Name of the continuum fr
# HIERARCH V500 PPAK P3 PIPE CONT MST = 0 / master TRACE used
# HIERARCH V500 PPAK P3 PIPE ARC = 'run226_00107.fits' / Name of the arc frame
# HIERARCH V500 PPAK P3 PIPE ARC MST = 0 / master ARC lamp used
# HIERARCH V500 PPAK P3 PIPE WOFFSET = 0.007 / wavelength offset of OI 5777 sky li
# HIERARCH V500 PPAK P3 PIPE WRMS = 0.048 / offset RMS of OI 5777 sky line
# HIERARCH V500 PIPE P3 APER FLUX = 16.825 / V_Johnson band flux (30.0arcsec diame
# HIERARCH V500 PIPE P3 APER ERR = 0.07000000000000001 / V_Johnson band error (30.
# HIERARCH V500 PIPE P3 RELFLUX START = 4500.0 / Start wave for poly fit
# HIERARCH V500 PIPE P3 RELFLUX END = 7000.0 / End wave for poly fit
# HIERARCH V500 PIPE P3 RELFLUX POLY0 = '1.000E+00' / Polynomial coefficient
# HIERARCH V500 PIPE P3 RELFLUX POLY1 = '3.907E-19' / Polynomial coefficient
# HIERARCH V500 PIPE P3 PIPE REGISTER = 1 / Possibilty of registering for this poi
# HIERARCH V500 PIPE P3 PIPE OFFX = 1.0 / IFU RA offset from ref coordinate
# HIERARCH V500 PIPE P3 PIPE OFFY = -4.5 / IFU DEC offset from ref coordinate
# HIERARCH V500 PIPE P3 PIPE CHISQ = 1.07 / CHISQ of image matching
# HIERARCH V500 PIPE P3 PIPE VALIDFIB = 326 / Valid fibers for image matching
# HIERARCH V500 PIPE P3 PIPE PHOTSCL = 0.952 / photometric scale factor
# HIERARCH V500 OBJDESC GALAXY = 'Object description'
# AUTHOR  = 'CALIFA Collaboration' / Creator of the dataset
# INTRUME = 'PMAS/PPAK'          / Insturment use for observations
# HIERARCH PIPE VERS = 2.2 / Pipeline version
# HIERARCH PIPE UNITS = '1e-16 erg/s/cm^2/A' / flux unit
# OBJECT  = 'NGC0192 '           / Target object
# CALIFAID=                   26 / CALIFAID of object
# HIERARCH V500 PIPE REDUDATE = '29-06-2015T05:34:02' / Date/Time the file was pro
# HIERARCH V500 PIPE GALEXT COR = 1 / Applied Galactic Extinction (0 NO,1 Yes)
# HIERARCH V500 PIPE GALEXT AV = 0.067 / Galactic extinction in V-Band (-1 if not)
# CRVAL3  =               3749.0
# CDELT3  =                  2.0
# CRPIX3  =                  1.0
# CRVAL2  =   0.8640188099176296 / DEC at CRPIX2 in deg
# CDELT2  =                  1.0
# CRPIX2  =                   33 / Ref pixel for WCS
# HIERARCH V500 INTCUBE = 'INVERSEDISTANCE' / Interpolation method to create the c
# HIERARCH V500 INTCUBEPARS = ' (sigma=0.75 | radius_limit=3.5 | min_fibers=1 )'
# WCSAXES =                    3 / Axes of the WCS
# WCSNAME = 'TELESCOPE'
# RADESYS = 'ICRS    '
# CTYPE1  = 'RA---TAN'           / Variable measured by the WCS
# CUNIT1  = 'deg     '           / Units
# CTYPE2  = 'DEC--TAN'           / Variable measured by the WCS
# CUNIT2  = 'deg     '           / Units
# CTYPE3  = 'WAVELENGTH'         / Spectral Axis Type
# CUNIT3  = 'Angstrom'           / Units
# CD1_1   = -0.00027777777777777 / Pixels in degress for X-axis
# CD1_2   =                  0.0
# CD2_1   =                  0.0
# CD2_2   = 0.000277777777777777 / Pixels in degress for Y-axis
# CD3_3   =                  2.0 / Linear dispersion (Angstrom/pixel)
# CD1_3   =                  0.0
# CD2_3   =                  0.0
# CD3_1   =                  0.0
# CD3_2   =                  0.0
# EQUINOX =               2000.0
# HIERARCH PIPE FILE VBAND = 'NGC0192.V.fits' / Synthetic V-band Fits image
# HIERARCH V500 DATE OBS = 20120913 / observation date
# FILENAME= 'NGC0192.V500.rscube.fits.gz' / File Name
# REGISTER=                    1 / Registering using SDSS images
# SDSSMAG = 'True    '           / Calculate SDSS 30arcsec aperture mag
# HIERARCH PIPE APER CUBE R = '12.970  ' / 30arcsec r band photometry from cube
# HIERARCH PIPE APER CUBE G = '13.765  ' / 30arcsec g band photometry from cube
# HIERARCH PIPE ABS SDSS FILE RATIO G = 0.9908319448927677 / ratio of SDSS photome
# HIERARCH PIPE ABS SDSS FILE RATIO R = 1.003690930920098 / ratio of SDSS photomet
# HIERARCH PIPE ABS SDSS FILE RATIO = 0.9972614379064331 / ratio of SDSS photometr
# HIERARCH APER FILE G = 13.775 / SDSS photometry (/home/sanchez/sda2/code/python/
# HIERARCH APER FILE R = 12.966 / SDSS photometry (/home/sanchez/sda2/code/python/
# HIERARCH PIPE REDUDATE = '29-06-2015T05:37:40' / Date/Time the file was produced
# HIERARCH PIPE ABS SDSS PY3D RATIO G = 0.9935735005868448 / ratio of SDSS photome
# HIERARCH PIPE ABS SDSS PY3D RATIO R = 1.005541501856043 / ratio of SDSS photomet
# HIERARCH PIPE ABS SDSS PY3D RATIO = 0.9995575012214442 / ratio of SDSS photometr
# HIERARCH APER PY3D G = 13.772 / SDSS photometry (/home/sanchez/sda2/code/python/
# HIERARCH APER PY3D R = 12.964 / SDSS photometry (/home/sanchez/sda2/code/python/
# HIERARCH MED_RATIO PSF SDSS = 0.1477283239364624 / factor median to match SDSS p
# KERNEL  = 'Moffat2D'           / Convolution Kernel used for the PSF
# FWHM    =                 1.88 / Best FHWM
# BETA    =    2.100000000000001 / Best BETA (Gaussian2D if None)
# HIERARCH SDSS FILTER = 'r       ' / Used SDSS Filter
# HIERARCH DRFIELD PSF_BETA = 2.966089963912964
# HIERARCH DRFIELD PSF_SIGMAP = 2.306502103805542
# HIERARCH DRFIELD PSF_WIDTH = 1.344220399856567
# HIERARCH FLAT_SDSS = T / SDSS Flat applied
# SHIFT1  =          0.888671875
# SHIFT2  =         -0.486328125
# ORIG_RA =    9.805927884661051
# ORIG_DEC=   0.8641539010714745
# WCS_COR =                    T
# HIERARCH PIPE FLAT APER CUBE R = '12.964  ' / 30arcsec r band photometry from cu
# HIERARCH PIPE FLAT ABS SDSS PY3D RATIO R = 0.9981596274917253 / ratio of SDSS ph
# HIERARCH PIPE FLAT ABS SDSS PY3D RATIO = 0.9844643639803773 / ratio of SDSS phot
# HIERARCH PIPE FLAT APER CUBE G = '13.758  ' / 30arcsec r band photometry from cu
# HIERARCH PIPE FLAT ABS SDSS PY3D RATIO G = 0.9844643639803773 / ratio of SDSS ph
# HIERARCH PIPE VMAG 3SIG = 23.75887194338206 / rough 3sigma depth (mag/arcsec**2)
# HIERARCH PIPE VMAG 5SIG = 23.59825863541023 / rough 3sigma depth (mag/arcsec**2)
# HIERARCH PIPE AREA 3SIG = 0.6273448773448773 / area (arcmin**2) above 3sigma lim
# MED_VEL =        4155.12346788 / systemic velocity km/s
# RMS_VEL =    12.24246175499414 / rms of systemic velocity (km/s)

# %% [markdown]
# Ahora haga un subplot que contemple 4 imágenes de la galaxia en 4 diferentes longitudes de onda de todo el espectro observado. Usted debe escoger estas cuatro longitudes de onda como se le antoje. Puede enchular los gráficos tanto como desee, es importante eso sí que todos contengan la información básica necesaria para que pueda ser visualizada científicamente. Recuerde importar los paquetes necesarios en caso de no haberlo hecho en algún bloque anterior.
#
# **Consejo**: Dentro de las longitudes de onda, se sugiere que escoja una cercana a los 6563 Angstrom.

# %%
delt1 = np.arange(0,header['NAXIS1']) - (header['CRPIX1']-1)
step1 = delt1*header['CD1_1']
ra = step1 + header['CRVAL1']
delt2 = np.arange(0,header['NAXIS2']) - (header['CRPIX2']-1)
step2 = delt2*header['CD2_2']
dec = step2 + header['CRVAL2']

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(figsize=(15,15),ncols=2,nrows=2)
g1=ax1.imshow(data[0],cmap='inferno',vmax=0.6,origin='lower')
fig.colorbar(g1,ax=ax1,label='Flux [10$^{-16}$ erg/s/cm$^2$/$\AA$]')
g2=ax2.imshow(data[1407],cmap='inferno',vmax=0.6,origin='lower')
fig.colorbar(g2,ax=ax2,label='Flux [10$^{-16}$ erg/s/cm$^2$/$\AA$]')
g3=ax3.imshow(data[200],cmap='inferno',vmax=0.6,origin='lower')
fig.colorbar(g3,ax=ax3,label='Flux [10$^{-16}$ erg/s/cm$^2$/$\AA$]')
g4=ax4.imshow(data[1300],cmap='inferno',vmax=0.6,origin='lower')

fig.colorbar(g4,ax=ax4,label='Flux [10$^{-16}$ erg/s/cm$^2$/$\AA$]')
s=pd.Series([3749 ,6563,4149,6349],index=[ax1,ax2,ax3,ax4])
for i in (ax1,ax2,ax3,ax4):
  i.set_title('NGC0192, longitud de onda de '+str(s[i])+' $\AA$')
  i.set_xlabel('Right Ascension [DEG]')
  i.set_ylabel('Declination [DEG]')
  i.set_xticks([0,25,50,75])
  i.set_xticklabels([round(ra[0],3),round(ra[25],3),round(ra[50],3),round(ra[75],3)])
  i.set_yticks([0,25,50,70])
  i.set_yticklabels([round(dec[0],3),round(dec[25],3),round(dec[50],3),round(dec[70],3)])

# %% [markdown]
# #3. Espectros de la Galaxia
#
# Como saben, a cada pixel le corresponde un espectro. Ahora haga un subplot que contemple el espectro de 9 pixeles de la galaxia. 8 de los 9 pixeles deben ser escogidos al azar, mientras que uno de ellos debe corresponder al espectro de los pixeles de referencia que el header indica. Puede enchular los gráficos tanto como desee, es importante eso sí que todos contengan la información básica necesaria para que pueda ser visualizada científicamente. Recuerde importar los paquetes necesarios en caso de no haberlo hecho en algún bloque anterior.
#
# Finalmente calcule el redshift al cual se encuentra el objeto, para ello puede indentificar las líneas de los espectros obtenidos en esta [página](http://skyserver.sdss.org/dr15/en/tools/chart/navi.aspx). El cálculo del redshift debe hacerse con la información de los espectros del fits. Ignore la rotación de la galaxia.
#
# **Hint:** Le puede ser útil saber que la línea de H$\alpha$ se encuentra centrada en 6563 Angstroms. La longitud de onda de las primeras líneas de la serie de Balmer las puede encontrar en [aquí](https://es.wikipedia.org/wiki/L%C3%ADneas_de_Balmer). Imprima en pantalla la operación a realizar y que línea o líneas usó para determinar el redshift al cual se encuentra la galaxia.

# %%
delt3 = np.arange(0,header['NAXIS3'])
step3 = delt3*header['CD3_3']
lo = step3 + header['CRVAL3']
fig, ax=plt.subplots(figsize=(20,20),nrows=3,ncols=3)
ax[0,0].plot(lo,data[:,32,37],color='r')
ax[0,1].plot(lo,data[:,25,10],color='b')
ax[0,2].plot(lo,data[:,66,15],color='g')
ax[1,0].plot(lo,data[:,34,55],color='y')
ax[1,1].plot(lo,data[:,22,43],color='k')
ax[1,2].plot(lo,data[:,39,19],color='c')
ax[2,0].plot(lo,data[:,53,25],color='m')
ax[2,1].plot(lo,data[:,71,49],color='orange')
ax[2,2].plot(lo,data[:,24,34])
rx=header['CRPIX1']
ry=header['CRPIX2']
t=np.array([['('+str(rx)+','+str(ry)+') '+'(pixel de referencia)','(11,26)','(16,67)'],['(56,35)','(44,23)','(20,40)'],['(26,54)','(50,54)','(35,25)']])
for i in range(3):
  for j in range(3):
    ax[i,j].set_xlabel('Wavelength [$\AA$]')
    ax[i,j].set_ylabel('Flux [10$^{-16}$ erg/s/cm$^2$/$\AA$]')
    ax[i,j].set_title('Espectro del pixel '+t[i,j])

# %%
s=data[:,33,38]
d=np.argmax(s)
red=(lo[d]/6563.0)-1
print('El redshift de el objeto observado es aproximadamente '+str(red))

# %% [markdown]
# #4. Coordenadas
#
# En esta parte deben crear una variable que contenga un objeto SkyCoord definido con los dos últimos dígitos de rut como ascención recta y declinación en el sistema ICRS (No contar el dígito verificador).
#
# **Ejemplo:** si su RUT es 12.345.678 - 9. La ascención recta y declinación para ese objeto debe ser 78°. Si los úlitmos dos dígitos son mayores que noventa, utilice solo el último.

# %%
from astropy.coordinates import SkyCoord
from astropy import units as u
#rut: 20413272-0
c=SkyCoord(ra=20*u.degree, dec=20*u.degree, frame='icrs')
print(c)
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (20., 20.)>

# %% [markdown]
# #5. Query: Imagen
#
# En esta parte haga un query a los datos del SDSS utilizando como coordenadas las definidas anteriormente en una región de radio 10 arcsec, además, asegúrese que los objetos de la busqueda cuentan con un espectro. En caso de no encontrar algo, multiplique el radio por 2 hasta encontrar un objeto. Extraiga el espectro y la fotometría en las bandas z e i.
#
# Imprima en pantalla el WCS header de alguno de los fits fotometría, y proceda a graficar las regiones mostradas en los dos fits fotométricos descargados. Puede enchular los gráficos tanto como desee, es importante eso sí que todos contengan la información básica necesaria para que pueda ser visualizada científicamente. Como los datos son del SDSS, ustedes encontraran una imagen de la placa entera, hagan un zoom mostrando de forma cercana el objeto que les debiese haber salido al azar, queda a su criterio cuanto deben ampliar la imagen ustedes.

# %%
#!pip install astroquery
from astroquery.sdss import SDSS
xid = SDSS.query_region(c, radius = 150*u.arcsec, spectro=True) #curiosamente con mi rut en 72 no encontraba objetos :c, recien usando 40000*u.arcsec encontro unos, asi que use el rut de mi mamá jeje
print(xid)
sp = SDSS.get_spectra(matches=xid)
img = SDSS.get_images(matches=xid, band='z') 
imu = SDSS.get_images(matches=xid, band='i') 
headeri=imu[0][0].header
wcsi=WCS(headeri)
print(wcsi)
print('\nHEADER:')
headeri
# Out:
#        ra              dec               objid        ... run2d  instrument
# ---------------- ---------------- ------------------- ... ------ ----------
# 19.9967991049197 19.9599488252149 1237679504327115362 ... v5_7_0       BOSS
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 20.009276318  19.8947931452
# CRPIX : 1025.0  745.0
# CD1_1 CD1_2  : 9.84644798214e-06  0.000109548750213
# CD2_1 CD2_2  : 0.000109535402264  -9.76090939666e-06
# NAXIS : 2048  1489
#
# HEADER:
# SIMPLE  =                    T /
# BITPIX  =                  -32 / 32 bit floating point
# NAXIS   =                    2
# NAXIS1  =                 2048
# NAXIS2  =                 1489
# EXTEND  =                    T /Extensions may be present
# BZERO   =              0.00000 /Set by MRD_SCALE
# BSCALE  =              1.00000 /Set by MRD_SCALE
# TAI     =        4739228722.09 / 1st row Number of seconds since Nov 17 1858
# RA      =            19.681455 / 1st row RA of telescope boresight (deg)
# DEC     =            19.396481 / 1st row Dec of telescope boresight (degrees)
# SPA     =              94.973  / 1st row Cam col position angle wrt N (deg)
# IPA     =              32.081  / 1st row Inst rotator position angle (deg)
# IPARATE =              0.0017  / 1st row Inst rotator anglr velocity (deg/sec)
# AZ      =            267.68840 / 1st row Azimuth (encoder) of tele (0=N?) (deg)
# ALT     =            34.161873 / 1st row Altitude (encoder) of tele (degrees)
# FOCUS   =           -165.00000 / 1st row - Focus piston (microns?)
# DATE-OBS= '2009-01-21'         / 1st row - TAI date
# TAIHMS  = '04:25:22.09'        / 1st row TAI time HH:MM:SS.SS
# COMMENT  TAI,RA,DEC,SPA,IPA,IPARATE,AZ,ALT,FOCUS at reading of col 0, row 0
# ORIGIN  = 'SDSS    '
# TELESCOP= '2.5m    '
# TIMESYS = 'TAI     '
# RUN     =                 7923 / Run number
# FRAME   =                  309 / Frame sequence number within the run
# CCDLOC  =                   25 / Survey location of CCD (e.g., rowCol)
# STRIPE  =                   74 / Stripe index number (23 <--> eta=0)
# STRIP   = 'S       '           / Strip in the stripe being tracked.
# FLAVOR  = 'science '           / Flavor of this run
# OBSERVER= 'elenam  '           / Observer
# SYS_SCN = 'mean    '           / System of the scan great circle (e.g., mean)
# EQNX_SCN=           2000.00    / Equinox of the scan great circle. (years)
# NODE    =           95.00000   / RA of the great circle's ascending node (deg)
# INCL    =           -20.00000  / Great circle's inclination wrt cel. eq. (deg)
# XBORE   =           22.74      / Boresight x offset from the array center (mm)
# YBORE   =           0.00       / Boresight x offset from the array center (mm)
# OBJECT  = '74 S    '           / e.g., 'stripe 50.6 degrees, north strip'
# EXPTIME = '53.907456'          / Exposure time (seconds)
# SYSTEM  = 'FK5     '           / System of the TCC coordinates (e.g., mean)
# CCDMODE = 'DRIFT   '           / 'STARING' or 'DRIFT'
# C_OBS   =                26322 / CCD row clock rate (usec/row)
# COLBIN  =                    1 / Binning factor perpendicular to the columns
# ROWBIN  =                    1 / Binning factor perpendicular to the rows
# DAVERS  = 'v15_13_1'           / Version of DA software
# SCDMETHD= 'sqrtDynamic'        / scdMethod
# SCDWIDTH=                 1280 / scdDisplayWidth
# SCDDECMF=                    1 / scdDecimateFactor
# SCDOFSET=                   40 / scdDisplayOffset
# SCDDYNTH=                  -22 / scdDynamicThresh
# SCDSTTHL=                   30 / scdStaticThreshL
# SCDSTTHR=                   30 / scdStaticThreshR
# SCDREDSZ=                  560 / scdReduceSize
# SCDSKYL =                    0 / scdSkyLeft
# SCDSKYR =                    0 / scdSkyRight
# COMMENT  CCD-specific parameters
# CAMROW  =                    2 / Row in the imaging camera
# BADLINES=                    0 / Number of bad lines in frame
# EQUINOX =              2000.00 /
# SOFTBIAS=                 1000 / software "bias" added to all DN
# BUNIT   = 'nanomaggy'          / 1 nanomaggy = 3.631e-6 Jy
# FILTER  = 'i       '           / filter used
# CAMCOL  =                    5 / column in the imaging camera
# VERSION = 'v5_6_3  '
# DERV_VER= 'NOCVS:v8_23'
# ASTR_VER= 'NOCVS:v5_24'
# ASTRO_ID= '2009-05-09T21:46:15 05664'
# BIAS_ID = 'PS      '
# FRAME_ID= '2009-09-18T21:20:26 22316'
# KO_VER  = 'devel   '
# PS_ID   = '2009-05-09T21:00:51 13045 camCol 5'
# ATVSN   = 'NOCVS:v5_24'        / ASTROTOOLS version tag
# RADECSYS= 'ICRS    '           / International Celestial Ref. System
# CTYPE1  = 'RA---TAN'           /Coordinate type
# CTYPE2  = 'DEC--TAN'           /Coordinate type
# CUNIT1  = 'deg     '           /Units
# CUNIT2  = 'deg     '           /Units
# CRPIX1  =        1025.00000000 /X of reference pixel
# CRPIX2  =        745.000000000 /Y of reference pixel
# CRVAL1  =        20.0092763180 /RA of reference pixel (deg)
# CRVAL2  =        19.8947931452 /Dec of reference pixel (deg)
# CD1_1   =    9.84644798214E-06 /RA deg per column pixel
# CD1_2   =    0.000109548750213 /RA deg per row pixel
# CD2_1   =    0.000109535402264 /Dec deg per column pixel
# CD2_2   =   -9.76090939666E-06 /Dec deg per row pixel
# HISTORY GSSSPUTAST: Sep 18 21:20:38 2009
# COMMENT  Calibration parameters
# COMMENT  Floats truncated at 10 binary digits with FLOATCOMPRESS
# NMGY    =           0.00707828 / Calibration factor [nMgy per count]
# NMGYIVAR=             0.347652 / Calibration factor inverse variance
# VERSIDL = '7.0     '           / Version of IDL
# VERSUTIL= 'v5_5_5  '           / Version of idlutils
# VERSPOP = 'v1_11_1 '           / Version of photoop product
# PCALIB  = '/clusterfs/riemann/raid006/bosswork/groups/boss/calib/2009-06-14/cal'
# PSKY    = '/clusterfs/riemann/raid006/bosswork/groups/boss/photo/sky' / Value of
# RERUN   = '301     '           / rerun
# HISTORY SDSS_FRAME_ASTROM: Astrometry fixed for dr9 Thu Jun 28 08:03:30 2012

# %%
datoz=img[0][0].data
datoi=imu[0][0].data
fig,cx=plt.subplots(figsize=(10,10),nrows=2)
gz=cx[0].imshow(datoz,cmap='plasma',vmax=0.6,origin='lower',vmin=0)
plt.colorbar(gz,ax=cx[0],label='Densidad de flujo [3.631$ \cdot 10^{-6}$ Jy]')
cx[0].grid(b=None)
gi=cx[1].imshow(datoi,cmap='plasma',vmax=1,origin='lower')
plt.colorbar(gi,ax=cx[1],label='Densidad de flujo [3.631$ \cdot 10^{-6}$ Jy]')
cx[1].grid(b=None)
b=['Z','I']
for i in range(2):
  cx[i].set_xlabel('Right Ascension [DEG]')
  cx[i].set_ylabel('Declination [DEG]')
  cx[i].set_title('Banda '+b[i])

# %%
imagenzoom=datoz[500:900,1250:1750]
plt.imshow(imagenzoom,cmap='plasma',vmax=0.6,origin='lower')
plt.colorbar(label='Densidad del flujo [3.631$ \cdot 10^{-6}$ Jy]')
plt.xlabel('Right Ascension [DEG]')
plt.ylabel('Declination [DEG]')
plt.title('Objeto en banda Z')
plt.grid(b=None)

# %% [markdown]
# #6. Query: Espectro
#
# En esta parte haga un gráfico con los datos espectroscópicos del objeto encontrado. Imprima en pantalla el WCS header. Puede enchular los gráficos tanto como desee, es importante eso sí que todos contengan la información básica necesaria para que pueda ser visualizada científicamente. Compare el objeto con el encontrado en esta [página](http://skyserver.sdss.org/dr15/en/tools/chart/navi.aspx), identifique las líneas y hagan que se vean en el espectro bien señalizadas.
